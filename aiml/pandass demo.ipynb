# %%
import pandas as pd

# %%
data = [10, 20, 30, 40, 50]
series = pd.Series(data)
print(series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
import pandas as pd

s = pd.Series([5, 10, 15, 20, 25])
s.sort_values(reversed)
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 import pandas as pd
#       3 s = pd.Series([5, 10, 15, 20, 25])
# ----> 4 s.sort_values(reversed)
#       5 print(s)
#
# TypeError: Series.sort_values() takes 1 positional argument but 2 were given
